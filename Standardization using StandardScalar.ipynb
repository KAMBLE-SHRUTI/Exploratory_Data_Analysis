# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('auto-mpg.csv.csv')

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df2 = df[['displacement', 'weight']]

# %%
df2
# Out:
#      displacement  weight
# 0           307.0    3504
# 1           350.0    3693
# 2           318.0    3436
# 3           304.0    3433
# 4           302.0    3449
# ..            ...     ...
# 393         140.0    2790
# 394          97.0    2130
# 395         135.0    2295
# 396         120.0    2625
# 397         119.0    2720
#
# [398 rows x 2 columns]

# %%
df2.describe()
# Out:
#        displacement       weight
# count    398.000000   398.000000
# mean     193.425879  2970.424623
# std      104.269838   846.841774
# min       68.000000  1613.000000
# 25%      104.250000  2223.750000
# 50%      148.500000  2803.500000
# 75%      262.000000  3608.000000
# max      455.000000  5140.000000

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()
print(ss)
# Out:
# StandardScaler()

# %%
df2 = ss.fit_transform(df2)

# %%
df2
# Out:
# array([[ 1.0906037 ,  0.63086987],
#        [ 1.5035143 ,  0.85433297],
#        [ 1.19623199,  0.55047045],
#        [ 1.06179598,  0.54692342],
#        [ 1.04259084,  0.56584093],
#        [ 2.26211751,  1.62049216],
#        [ 2.50218182,  1.63586264],
#        [ 2.36774581,  1.58620417],
#        [ 2.51178439,  1.71980909],
#        [ 1.88761719,  1.03996105],
#        [ 1.82039919,  0.7006282 ],
#        [ 1.40748858,  0.75501604],
#        [ 1.98364292,  0.93473239],
#        [ 2.51178439,  0.1366499 ],
#        [-0.77229532, -0.70754402],
#        [ 0.04392332, -0.16248324],
#        [ 0.0535259 , -0.23224156],
#        [ 0.06312847, -0.45333997],
#        [-0.92593647, -0.99367137],
#        [-0.92593647, -1.34246298],
#        [-0.80110303, -0.35284069],
#        [-0.82991075, -0.63896804],
#        [-0.85871847, -0.70399699],
#        [-0.69547474, -0.87070755],
#        [ 0.0535259 , -0.38121696],
#        [ 1.59954003,  1.94445453],
#        [ 1.0906037 ,  1.66187422],
# ...

# %%
df2 = pd.DataFrame(data = df2,columns=['Displacement','Weight'])

# %%
df2
# Out:
#      Displacement    Weight
# 0        1.090604  0.630870
# 1        1.503514  0.854333
# 2        1.196232  0.550470
# 3        1.061796  0.546923
# 4        1.042591  0.565841
# ..            ...       ...
# 393     -0.513026 -0.213324
# 394     -0.925936 -0.993671
# 395     -0.561039 -0.798585
# 396     -0.705077 -0.408411
# 397     -0.714680 -0.296088
#
# [398 rows x 2 columns]

# %%
df2.describe()
# Out:
#        Displacement        Weight
# count  3.980000e+02  3.980000e+02
# mean  -8.312725e-17 -9.902743e-17
# std    1.001259e+00  1.001259e+00
# min   -1.204411e+00 -1.604943e+00
# 25%   -8.563178e-01 -8.828266e-01
# 50%   -4.314040e-01 -1.973624e-01
# 75%    6.584879e-01  7.538337e-01
# max    2.511784e+00  2.565185e+00

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df = pd.concat([df,df2], axis=1)

# %%
df.drop(['displacement','weight'], axis=1, inplace=True)

# %%
df
# Out:
#       mpg  cylinders horsepower  acceleration  model year  origin  \
# 0    18.0          8        130          12.0          70       1
# 1    15.0          8        165          11.5          70       1
# 2    18.0          8        150          11.0          70       1
# 3    16.0          8        150          12.0          70       1
# 4    17.0          8        140          10.5          70       1
# ..    ...        ...        ...           ...         ...     ...
# 393  27.0          4         86          15.6          82       1
# 394  44.0          4         52          24.6          82       2
# 395  32.0          4         84          11.6          82       1
# 396  28.0          4         79          18.6          82       1
# 397  31.0          4         82          19.4          82       1
#
#                       car name  Displacement    Weight
# 0    chevrolet chevelle malibu      1.090604  0.630870
# 1            buick skylark 320      1.503514  0.854333
# ...

# %%
df.shape
# Out:
# (398, 9)

# %%
df.describe()
# Out:
#               mpg   cylinders  acceleration  model year      origin  \
# count  398.000000  398.000000    398.000000  398.000000  398.000000
# mean    23.514573    5.454774     15.568090   76.010050    1.572864
# std      7.815984    1.701004      2.757689    3.697627    0.802055
# min      9.000000    3.000000      8.000000   70.000000    1.000000
# 25%     17.500000    4.000000     13.825000   73.000000    1.000000
# 50%     23.000000    4.000000     15.500000   76.000000    1.000000
# 75%     29.000000    8.000000     17.175000   79.000000    2.000000
# max     46.600000    8.000000     24.800000   82.000000    3.000000
#
#        Displacement        Weight
# count  3.980000e+02  3.980000e+02
# mean  -8.312725e-17 -9.902743e-17
# std    1.001259e+00  1.001259e+00
# min   -1.204411e+00 -1.604943e+00
# 25%   -8.563178e-01 -8.828266e-01
# 50%   -4.314040e-01 -1.973624e-01
# 75%    6.584879e-01  7.538337e-01
# max    2.511784e+00  2.565185e+00
